# %%
import sklearn
import pandas as pd
from sklearn import datasets
import seaborn as sns
from matplotlib import pyplot as plt
from scipy.stats import normaltest

# %%
X, Y = datasets.load_diabetes(return_X_y=True)
full_database = pd.DataFrame(X,columns=['age','sex','bmi','bp','s1_tc','s2_ldl','s3_hdl','s4_tch','s5_ltg','s6_glu'])
full_database['disease_progression'] = Y

# %%
print("EXPLORATORY DATA ANALYSIS\n")


full_database
# Out:
# EXPLORATORY DATA ANALYSIS
#           age       sex       bmi        bp     s1_tc    s2_ldl    s3_hdl  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017282 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081414  0.083740  0.027809  0.173816
#
#        s4_tch    s5_ltg    s6_glu  disease_progression
# 0   -0.002592  0.019908 -0.017646                151.0
# 1   -0.039493 -0.068330 -0.092204                 75.0
# 2   -0.002592  0.002864 -0.025930                141.0
# 3    0.034309  0.022692 -0.009362                206.0
# 4   -0.002592 -0.031991 -0.046641                135.0
# ..        ...       ...       ...                  ...
# 437 -0.002592  0.031193  0.007207                178.0
# 438  0.034309 -0.018118  0.044485                104.0
# 439 -0.011080 -0.046879  0.015491                132.0
# 440  0.026560  0.044528 -0.025930                220.0
# 441 -0.039493 -0.004220  0.003064                 57.0
#
# [442 rows x 11 columns]

# %%
print("To get more information about each variable:\n")

print("Total of lines:",full_database.shape[0])
print("Unique values of sex:", len(full_database.sex.unique()))

print("-"*100)

print("Once all the other variables were quantitatives:\n")

full_database.drop('sex',axis=1).describe()
# Out:
# To get more information about each variable:
#
# Total of lines: 442
# Unique values of sex: 2
# ----------------------------------------------------------------------------------------------------
# Once all the other variables were quantitatives:
#                 age           bmi            bp         s1_tc        s2_ldl  \
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean  -3.634285e-16 -8.045349e-16  1.281655e-16 -8.835316e-17  1.327024e-16
# std    4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02
# min   -1.072256e-01 -9.027530e-02 -1.123996e-01 -1.267807e-01 -1.156131e-01
# 25%   -3.729927e-02 -3.422907e-02 -3.665645e-02 -3.424784e-02 -3.035840e-02
# 50%    5.383060e-03 -7.283766e-03 -5.670611e-03 -4.320866e-03 -3.819065e-03
# 75%    3.807591e-02  3.124802e-02  3.564384e-02  2.835801e-02  2.984439e-02
# max    1.107267e-01  1.705552e-01  1.320442e-01  1.539137e-01  1.987880e-01
#
#              s3_hdl        s4_tch        s5_ltg        s6_glu  \
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean  -4.574646e-16  3.777301e-16 -3.830854e-16 -3.412882e-16
# std    4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02
# min   -1.023071e-01 -7.639450e-02 -1.260974e-01 -1.377672e-01
# 25%   -3.511716e-02 -3.949338e-02 -3.324879e-02 -3.317903e-02
# 50%   -6.584468e-03 -2.592262e-03 -1.947634e-03 -1.077698e-03
# 75%    2.931150e-02  3.430886e-02  3.243323e-02  2.791705e-02
# max    1.811791e-01  1.852344e-01  1.335990e-01  1.356118e-01
#
#        disease_progression
# count           442.000000
# mean            152.133484
# std              77.093005
# min              25.000000
# 25%              87.000000
# 50%             140.500000
# 75%             211.500000
# max             346.000000

# %%
fig, axes = plt.subplots(1, 3)

axes[0].set_title("Age")
sns.histplot(full_database, x="age",ax=axes[0])
axes[1].set_title("bmi")
sns.histplot(full_database, x="bmi", ax=axes[1])
axes[2].set_title("bp")
sns.histplot(full_database, x="bp", ax=axes[2])

plt.show()

# %%
fig, axes = plt.subplots(2, 3)

axes[0,0].set_title("s1_tc")
sns.histplot(full_database, x="s1_tc",ax=axes[0,0])
axes[0,1].set_title("s2_ldl")
sns.histplot(full_database, x="s2_ldl", ax=axes[0,1])
axes[0,2].set_title("s3_hdl")
sns.histplot(full_database, x="s3_hdl", ax=axes[0,2])
axes[1,0].set_title("s4_tch")
sns.histplot(full_database, x="s4_tch",ax=axes[1,0])
axes[1,1].set_title("s5_ltg")
sns.histplot(full_database, x="s5_ltg", ax=axes[1,1])
axes[1,2].set_title("s6_glu")
sns.histplot(full_database, x="s6_glu", ax=axes[1,2])

plt.show()

# %%
alpha = 0.05
print("Normaltest (using an alpha of {}):".format(alpha))
for column in full_database:
    _,p_value = normaltest(full_database[column])
    H0 = p_value <= alpha
    if H0:
        print(column, "is not normal - P-value:",p_value)
    else:
        print(column, "is normal - P-value:",p_value)
# Out:
# Normaltest (using an alpha of 0.05):
# age is not normal - P-value: 1.0228182153992174e-05
# sex is not normal - P-value: 0.0
# bmi is not normal - P-value: 7.262331793832793e-06
# bp is not normal - P-value: 0.000405512025210947
# s1_tc is not normal - P-value: 0.003682130413975457
# s2_ldl is not normal - P-value: 0.00012149451358986439
# s3_hdl is not normal - P-value: 4.007267957312441e-11
# s4_tch is not normal - P-value: 1.3014776207789513e-08
# s5_ltg is not normal - P-value: 0.0394872577910996
# s6_glu is normal - P-value: 0.11673477122976696
# disease_progression is not normal - P-value: 1.1743678801847827e-14

# %%
print("Correlation between variables (pearson method):\n")

corr_var = full_database.corr(method ='pearson')

corr_var
# Out:
# Correlation between variables (pearson method):
#                           age       sex       bmi        bp     s1_tc  \
# age                  1.000000  0.173737  0.185085  0.335427  0.260061
# sex                  0.173737  1.000000  0.088161  0.241013  0.035277
# bmi                  0.185085  0.088161  1.000000  0.395415  0.249777
# bp                   0.335427  0.241013  0.395415  1.000000  0.242470
# s1_tc                0.260061  0.035277  0.249777  0.242470  1.000000
# s2_ldl               0.219243  0.142637  0.261170  0.185558  0.896663
# s3_hdl              -0.075181 -0.379090 -0.366811 -0.178761  0.051519
# s4_tch               0.203841  0.332115  0.413807  0.257653  0.542207
# s5_ltg               0.270777  0.149918  0.446159  0.393478  0.515501
# s6_glu               0.301731  0.208133  0.388680  0.390429  0.325717
# disease_progression  0.187889  0.043062  0.586450  0.441484  0.212022
#
#                        s2_ldl    s3_hdl    s4_tch    s5_ltg    s6_glu  \
# age                  0.219243 -0.075181  0.203841  0.270777  0.301731
# sex                  0.142637 -0.379090  0.332115  0.149918  0.208133
# bmi                  0.261170 -0.366811  0.413807  0.446159  0.388680
# bp                   0.185558 -0.178761  0.257653  0.393478  0.390429
# s1_tc                0.896663  0.051519  0.542207  0.515501  0.325717
# s2_ldl               1.000000 -0.196455  0.659817  0.318353  0.290600
# s3_hdl              -0.196455  1.000000 -0.738493 -0.398577 -0.273697
# s4_tch               0.659817 -0.738493  1.000000  0.617857  0.417212
# s5_ltg               0.318353 -0.398577  0.617857  1.000000  0.464670
# s6_glu               0.290600 -0.273697  0.417212  0.464670  1.000000
# disease_progression  0.174054 -0.394789  0.430453  0.565883  0.382483
#
#                      disease_progression
# age                             0.187889
# sex                             0.043062
# bmi                             0.586450
# bp                              0.441484
# s1_tc                           0.212022
# s2_ldl                          0.174054
# s3_hdl                         -0.394789
# s4_tch                          0.430453
# s5_ltg                          0.565883
# s6_glu                          0.382483
# disease_progression             1.000000

# %%
print("Correlation heatmap")

sns.heatmap(corr_var)
plt.show()
# Out:
# Correlation heatmap
